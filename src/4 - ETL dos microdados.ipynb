# %% [markdown]
# # Importação de bibliotecas

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text

# %% [markdown]
# # Instância de conexão com o banco de dados

# %%
usuario = "root"
senha = "root"
url = "localhost"
porta = "3306"
banco = "ENEM_OLTP"

# Criar uma conexão com o banco de dados MySQL
engine = create_engine(f"mysql+pymysql://{usuario}:{senha}@{url}:{porta}/{banco}")

# %% [markdown]
# # Instância de conexão com o banco de dados DataMart

# %%
usuario = "root"
senha = "root"
url = "localhost"
porta = "3306"
banco = "ENEM_DM"

# Criar uma conexão com o banco de dados MySQL
engine_dm = create_engine(f"mysql+pymysql://{usuario}:{senha}@{url}:{porta}/{banco}")

# %% [markdown]
# # Criação da tabela dimensão de participantes

# %%
query = "SELECT * FROM PARTICIPANTES"
df = pd.read_sql(query, con=engine)

colunas = df.columns.tolist()

df["SK_PARTICIPANTES"] = np.arange(1, len(df) + 1)

df = df[["SK_PARTICIPANTES"] + colunas]

dimensoes = [
    "DIM_FAIXA_ETARIA",
    "DIM_SEXO",
    "DIM_ESTADO_CIVIL",
    "DIM_COR_RACA",
    "DIM_NACIONALIDADE",
    "DIM_ST_CONCLUSAO",
    "DIM_ANO_CONCLUIU",
    "DIM_ESCOLA",
    "DIM_ENSINO",
    "DIM_TREINEIRO",
]

for dimensao in dimensoes:
    query = f"SELECT * FROM {dimensao}"
    df_dim = pd.read_sql(query, con=engine_dm)
    df = df.merge(df_dim, on=df_dim.columns[1], how="left")
    df = df.drop(columns=df_dim.columns[1:])

colunas = df.columns.tolist()

colunas_sk = [
    coluna
    for coluna in colunas
    if coluna.startswith("SK_") and not coluna.startswith("SK_PARTICIPANTES")
]

df = df.replace(np.nan, None)

display(df.head())

with engine_dm.connect() as connection:
    df.to_sql(f"DIM_PARTICIPANTES", if_exists="replace", con=connection, index=False)
    connection.execute(
        text(
            """
            ALTER TABLE DIM_PARTICIPANTES
            ADD PRIMARY KEY (SK_PARTICIPANTES)
            """
        )
    )
    connection.execute(
        text(
            """
            ALTER TABLE DIM_PARTICIPANTES
            MODIFY COLUMN SK_SEXO BIGINT
            """
        )
    )

    connection.execute(
        text(
            """
            ALTER TABLE DIM_PARTICIPANTES
            MODIFY COLUMN SK_ENSINO BIGINT
            """
        )
    )

    connection.execute(
        text(
            """
            ALTER TABLE DIM_PARTICIPANTES
            ENGINE = InnoDB
            """
        )
    )
    for coluna in colunas_sk:
        connection.execute(
            text(
                f"""
                ALTER TABLE DIM_PARTICIPANTES
                ADD CONSTRAINT FK_DIM_PARTICIPANTES_{coluna}
                FOREIGN KEY ({coluna}) REFERENCES DIM_{coluna[3:]}({coluna}) ON DELETE CASCADE
                """
            )
        )

print(f"Dimensão PARTICIPANTES criada com sucesso! Total de registros: {len(df)}")
# Out:
#    SK_PARTICIPANTES  NU_INSCRICAO  SK_FAIXA_ETARIA  SK_SEXO  SK_ESTADO_CIVIL  \
# 0                 1  210058044217                5        2                2
# 1                 2  210058044218                2        2                2
# 2                 3  210058044219                2        2                2
# 3                 4  210058044220               11        2                2
# 4                 5  210058044221               11        1                2
#
#    SK_COR_RACA  SK_NACIONALIDADE  SK_ST_CONCLUSAO  SK_ANO_CONCLUIU  SK_ESCOLA  \
# 0            4                 2                2                1          2
# 1            2                 2                2                1          3
# 2            2                 2                3                1          1
# 3            4                 2                1                9          1
# 4            3                 2                1                9          1
#
#   SK_ENSINO  SK_TREINEIRO
# 0       1.0             1
# 1       1.0             1
# 2      None             2
# 3      None             1
# 4      None             1
# Dimensão PARTICIPANTES criada com sucesso! Total de registros: 1000000

# %% [markdown]
# # Criação da tabela fato de notas dos participantes

# %%
query = "SELECT * FROM NOTAS"
df = pd.read_sql(query, con=engine)

colunas = df.columns.tolist()

df["SK_NOTAS"] = np.arange(1, len(df) + 1)

df = df[["SK_NOTAS"] + colunas]

dimensoes = [
    "DIM_PARTICIPANTES",
    "DIM_TEMPO",
    "DIM_PRESENCA_CN",
    "DIM_PRESENCA_CH",
    "DIM_PRESENCA_LC",
    "DIM_PRESENCA_MT",
    "DIM_LINGUA",
    "DIM_STATUS_REDACAO",
]

for dimensao in dimensoes:
    query = f"SELECT * FROM {dimensao}"
    df_dim = pd.read_sql(query, con=engine_dm)
    df = df.merge(df_dim, on=df_dim.columns[1], how="left")
    df = df.drop(columns=df_dim.columns[1:])

colunas = df.columns.tolist()

colunas_sk = [
    coluna
    for coluna in colunas
    if coluna.startswith("SK_") and not coluna.startswith("SK_NOTAS")
]

colunas_notas = [
    coluna
    for coluna in colunas
    if coluna.startswith("NU_")
    and not coluna.startswith("NU_INSCRICAO")
    and not coluna.startswith("NU_ANO")
]

df = df.replace(np.nan, None)

df = df[["SK_NOTAS"] + colunas_sk + colunas_notas]

display(df.head())

with engine_dm.connect() as connection:
    df.to_sql(f"FAT_NOTAS", if_exists="replace", con=connection, index=False)
    connection.execute(
        text(
            """
            ALTER TABLE FAT_NOTAS
            ADD PRIMARY KEY (SK_NOTAS)
            """
        )
    )
    connection.execute(
        text(
            """
            ALTER TABLE FAT_NOTAS
            MODIFY COLUMN SK_STATUS_REDACAO BIGINT
            """
        )
    )

    for coluna in colunas_notas:
        connection.execute(
            text(
                f"""
                ALTER TABLE FAT_NOTAS
                MODIFY COLUMN {coluna} DECIMAL(5,1)
                """
            )
        )

    connection.execute(
        text(
            """
            ALTER TABLE FAT_NOTAS
            ENGINE = InnoDB
            """
        )
    )

    for coluna in colunas_sk:
        connection.execute(
            text(
                f"""
                ALTER TABLE FAT_NOTAS
                ADD CONSTRAINT FK_FAT_NOTAS_{coluna}
                FOREIGN KEY ({coluna}) REFERENCES DIM_{coluna[3:]}({coluna}) ON DELETE CASCADE
                """
            )
        )

print(f"Fato NOTAS criada com sucesso! Total de registros: {len(df)}")
# Out:
#    SK_NOTAS  SK_PARTICIPANTES  SK_TEMPO  SK_PRESENCA_CN  SK_PRESENCA_CH  \
# 0         1            246779        26               1               1
# 1         2            445914        26               1               1
# 2         3            924947        26               2               2
# 3         4            650884        26               2               2
# 4         5            569802        26               2               2
#
#    SK_PRESENCA_LC  SK_PRESENCA_MT  SK_LINGUA SK_STATUS_REDACAO NU_NOTA_CN  \
# 0               1               1          1              None       None
# 1               1               1          1              None       None
# 2               2               2          2               1.0      502.0
# 3               2               2          1               1.0      459.0
# 4               2               2          1               1.0      402.5
#
#   NU_NOTA_CH NU_NOTA_LC NU_NOTA_MT NU_NOTA_REDACAO
# 0       None       None       None            None
# 1       None       None       None            None
# 2      498.9      475.6      363.2           700.0
# 3      508.5      507.2      466.7           880.0
# 4      379.2      446.9      338.3           560.0
# Fato NOTAS criada com sucesso! Total de registros: 1000000

# %% [markdown]
# # Criação da tabela fato do questionário sócio-econômico

# %%
query = "SELECT * FROM QUESTIONARIO"
df = pd.read_sql(query, con=engine)

colunas = df.columns.tolist()

df["SK_QUESTIONARIO"] = np.arange(1, len(df) + 1)

df = df[["SK_QUESTIONARIO"] + colunas]

dimensoes = ["DIM_PARTICIPANTES", "DIM_TEMPO"] + [
    f"DIM_RESP_QUESTAO_{i}" for i in range(1, 26)
]

for dimensao in dimensoes:
    query = f"SELECT * FROM {dimensao}"
    df_dim = pd.read_sql(query, con=engine_dm)
    df = df.merge(df_dim, on=df_dim.columns[1], how="left")
    df = df.drop(columns=df_dim.columns[1:])

colunas = df.columns.tolist()

colunas_sk = [
    coluna
    for coluna in colunas
    if coluna.startswith("SK_") and not coluna.startswith("SK_QUESTIONARIO")
]

df = df.replace(np.nan, None)

df = df[["SK_QUESTIONARIO"] + colunas_sk]

display(df.head())

with engine_dm.connect() as connection:
    df.to_sql(f"FAT_QUESTIONARIO", if_exists="replace", con=connection, index=False)
    connection.execute(
        text(
            """
            ALTER TABLE FAT_QUESTIONARIO
            ADD PRIMARY KEY (SK_QUESTIONARIO)
            """
        )
    )

    connection.execute(
        text(
            """
            ALTER TABLE FAT_QUESTIONARIO
            ENGINE = InnoDB
            """
        )
    )

    for coluna in colunas_sk:
        connection.execute(
            text(
                f"""
                ALTER TABLE FAT_QUESTIONARIO
                ADD CONSTRAINT FK_FAT_QUESTIONARIO_{coluna}
                FOREIGN KEY ({coluna}) REFERENCES DIM_{coluna[3:]}({coluna}) ON DELETE CASCADE
                """
            )
        )

print(f"Fato QUESTIONARIO criada com sucesso! Total de registros: {len(df)}")
# Out:
#    SK_QUESTIONARIO  SK_PARTICIPANTES  SK_TEMPO  SK_RESP_QUESTAO_1  \
# 0                1            246779        26                  1
# 1                2            445914        26                  6
# 2                3            924947        26                  8
# 3                4            650884        26                  4
# 4                5            569802        26                  2
#
#    SK_RESP_QUESTAO_2  SK_RESP_QUESTAO_3  SK_RESP_QUESTAO_4  SK_RESP_QUESTAO_5  \
# 0                  6                  5                  4                  5
# 1                  5                  5                  2                  3
# 2                  5                  3                  6                  5
# 3                  4                  2                  2                  5
# 4                  2                  1                  1                  4
#
#    SK_RESP_QUESTAO_6  SK_RESP_QUESTAO_7  ...  SK_RESP_QUESTAO_16  \
# 0                  6                  3  ...                   3
# 1                  8                  1  ...                   2
# 2                  3                  1  ...                   2
# 3                  3                  1  ...                   1
# 4                  2                  1  ...                   1
#
#    SK_RESP_QUESTAO_17  SK_RESP_QUESTAO_18  SK_RESP_QUESTAO_19  \
# 0                   3                   2                   2
# 1                   1                   2                   2
# 2                   1                   1                   2
# 3                   1                   1                   2
# 4                   1                   1                   2
#
#    SK_RESP_QUESTAO_20  SK_RESP_QUESTAO_21  SK_RESP_QUESTAO_22  \
# 0                   1                   2                   2
# 1                   1                   1                   3
# 2                   1                   1                   1
# 3                   1                   1                   4
# 4                   1                   1                   2
#
#    SK_RESP_QUESTAO_23  SK_RESP_QUESTAO_24  SK_RESP_QUESTAO_25
# 0                   1                   1                   2
# 1                   1                   4                   2
# 2                   1                   1                   2
# 3                   1                   1                   2
# 4                   1                   1                   1
#
# [5 rows x 28 columns]
# Fato QUESTIONARIO criada com sucesso! Total de registros: 1000000
